# %%
import pandas
import numpy
from matplotlib import pyplot as plt
import seaborn
plt.style.use('ggplot')
seaborn.set_style('dark',rc={'axes.labelcolor':'white','xtick.color':'white','ytick.color':'white'})
# %matplotlib notebook
import datetime
pandas.set_option('display.float_format', '{:20,.2f}'.format)   #suppressing scientific notation
idx = pandas.IndexSlice

# %%
test = pandas.read_excel('paradox_charts.xlsx','Sheet1')

# %%
fig, ax = plt.subplots()
ax.grid()
ax2 = ax.twinx()
ax.plot('TOPIX Index',data=test,c='r')
ax.plot('TOPIX Index future',data=test, c='y')
ax2.plot('FTSE 100',data=test,c='b')
ax.legend(['TOIX Index','TOPIX Index future'])
ax2.legend(['FTSE 100'])
ax.set_xlabel('Timestamps')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test
# Out:
#                   TOPIX Index   TOPIX Index future             FTSE 100
# 01:00:00             1,635.03             1,639.03                  nan
# 01:01:00             1,634.84             1,638.84                  nan
# 01:02:00             1,635.63             1,639.63                  nan
# 01:03:00             1,636.46             1,640.46                  nan
# 01:04:00             1,636.45             1,640.45                  nan
# 01:05:00             1,637.20             1,641.20                  nan
# 01:06:00             1,637.49             1,641.49                  nan
# 01:07:00             1,638.33             1,642.33                  nan
# 01:08:00             1,637.94             1,641.94                  nan
# 01:09:00             1,638.54             1,642.54                  nan
# 01:10:00             1,637.84             1,641.84                  nan
# 01:11:00             1,636.71             1,640.71                  nan
# ...
